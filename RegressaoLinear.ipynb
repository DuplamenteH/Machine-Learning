# %% [markdown]
# <a href="https://colab.research.google.com/github/DuplamenteH/Machine-Learning/blob/master/RegressaoLinear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Entendendo os Dados.

# %%
import pandas as pd      
import matplotlib.pyplot as plt  
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
filmes = pd.read_csv('drive/My Drive/DadosAlura/regressao_linear_alura.csv')
filmes.head()
# Out:
#    movieId  ... Bilheteria (pessoas)
# 0        1  ...          5623234.602
# 1        2  ...          5714951.757
# 2        3  ...          9524339.124
# 3        4  ...          6331568.779
# 4        5  ...          6409617.277
#
# [5 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
plt.scatter(filmes['Investimento (em milhoes)'],filmes['Bilheteria (pessoas)'])
plt.show()

# %%
sample = filmes.sample(n=200)

# %%
sample.head()
# Out:
#       movieId  ... Bilheteria (pessoas)
# 4673     6506  ...          8903336.476
# 801       992  ...          8462824.898
# 5249     7831  ...          7954728.143
# 1323     1665  ...          6954014.628
# 6077    32211  ...          7029780.824
#
# [5 rows x 4 columns]

# %%
x = sample['Investimento (em milhoes)']
y = sample['Bilheteria (pessoas)']

# %%
plt.figure(figsize=(20,10))
plt.scatter(x,y)
plt.show()

# %%
filmes.tail()
# Out:
#       movieId  ... Bilheteria (pessoas)
# 9120   162672  ...         6.318999e+06
# 9121   163056  ...         5.300340e+06
# 9122   163949  ...         6.945211e+06
# 9123   164977  ...         6.459004e+06
# 9124   164979  ...         1.063624e+07
#
# [5 rows x 4 columns]

# %% [markdown]
# #Separação das variaveis independentes.

# %%
filmes_investimento = filmes['Investimento (em milhoes)']
filmes_bilheteria = filmes['Bilheteria (pessoas)']

# %% [markdown]
# #Divisão do treino e do Teste

# %%
treino, teste, treino_marcacoes, teste_marcacoes =  train_test_split(filmes_investimento, filmes_bilheteria,test_size=0.3)

# %%
treino = np.array(treino).reshape(len(treino), 1)
teste = np.array(teste).reshape(len(teste),1)

# %% [markdown]
# #Criação do Modelo

# %%
modelo = LinearRegression()
modelo.fit(treino,treino_marcacoes)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
